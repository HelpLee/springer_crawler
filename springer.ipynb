# %%
#!usr/bin/env python  
# -*- coding:utf-8 -*-
""" 
@author:Lee HaiBo
@filename: journal_statistics.py
@Software:PyCharm
@time: 2021/8/27, 10:19
@email:lntulhb@163.com
@function: Springer journal statistics for recent articles
"""
import requests
import re
import os
import csv
from lxml import etree
import time

# %%
import requests
import re
import os
import csv
import time
from lxml import etree

# User-Agent header for requests
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.87 Safari/537.36 SE 2.X MetaSr 1.0'
}

# Create a directory for storing journal data if it does not exist
if not os.path.exists('./Journal_Acceptance_Statistics'):
    os.mkdir('./Journal_Acceptance_Statistics')


# Replace spaces in a string with "+"
def replace_space(string):
    return string.replace(' ', '+')


# Query volume and issue for specific journal
def query_volume_issue():
    print('Enter the volume and issue numbers (e.g., 1-1):')
    vol_issue_input = input('Volume-Issue (e.g., 1-1): ')

    # Construct URL
    url = f'https://link.springer.com/journal/{journal_id}/volumes-and-issues/{vol_issue_input}'
    print(f"Fetching data from URL: {url}")

    # Parse volume and issue numbers
    vol_issue_pattern = r'.*?volumes-and-issues/(\d+)-(\d+)$'
    vol_issue_match = re.findall(vol_issue_pattern, url, re.S)
    volume, issue = vol_issue_match[0]

    # Fetch the webpage
    response = requests.get(url=url, headers=headers).text

    # Extract article links
    article_link_pattern = r'<h3 class="c-card__title">.*?<a href="(.*?)".*?</h3>'
    article_links = re.findall(article_link_pattern, response, re.S)

    # Extract journal title
    title_pattern = r'<a href="/journal.*?>(.*?)</a>'
    journal_title = re.findall(title_pattern, response, re.S)[0]

    # Extract the number of articles
    article_count_pattern = r'<p class="app-volumes-and-issues__copy">(.*?)articles in this issue<\/p>'
    article_count = re.findall(article_count_pattern, response, re.S)[0]

    print(f'Starting to fetch articles for {journal_title}, Volume {volume}, Issue {issue}...')
    print(f'Total articles: {article_count}')

    # Fetch articles
    all_articles = []
    for i, article_url in enumerate(article_links):
        print(f"Fetching article {i+1}/{article_count}...")
        article_response = requests.get(url=article_url, headers=headers).text

        # Extract dates and their labels
        date_label_pattern = r'<li class="c-bibliographic-information__list-item"><p>(.*?)<span class="u-hide">: .*?</span>.*?</p></li>'
        date_labels = re.findall(date_label_pattern, article_response, re.S)

        date_pattern = r'<span class="c-bibliographic-information__value"><time datetime="(.*?)".*?</span>'
        dates = re.findall(date_pattern, article_response, re.S)

        article_data = dict(zip(date_labels, dates))
        all_articles.append(article_data)

    # Save results to CSV
    clean_title = re.sub(r'[<>:"/\\|?*]', '', journal_title)
    file_path = f'./Journal_Acceptance_Statistics/{clean_title}_Volume_{volume}_Issue_{issue}.csv'
    fieldnames = ['Received', 'Revised', 'Accepted', 'Published', 'Issue Date']

    with open(file_path, 'w', encoding='utf-8', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(all_articles)

    print(f"Data saved to {file_path}")


# Query recent articles for a journal
def query_recent_articles():
    count = 0
    num_articles = input('Enter the number of recent articles to query: ')

    # Ensure the input is a valid number
    while not num_articles.isdigit():
        num_articles = input('Invalid input. Please enter a valid number: ')

    num_articles = int(num_articles)

    for issue_url in journal_issue_links:
        print(f"Processing URL: {issue_url}")
        response = requests.get(url=issue_url, headers=headers).text

        # Parse volume and issue numbers
        vol_issue_pattern = r'.*?volumes-and-issues/(\d+)-(\d+)$'
        vol_issue_match = re.findall(vol_issue_pattern, issue_url, re.S)
        volume, issue = vol_issue_match[0]

        # Extract article links
        article_link_pattern = r'<a href="(https://link\.springer\.com/article/.*?)"'
        article_links = re.findall(article_link_pattern, response)

        print(f"Fetching articles for Volume {volume}, Issue {issue}...")

        # Iterate through articles
        for article_url in article_links:
            article_page = requests.get(url=article_url, headers=headers).text

            # Extract dates and names for the articles
            date_label_pattern = r'<li class="c-bibliographic-information__list-item"><p>(.*?)<span class="u-hide">: .*?</span>.*?</p></li>'
            date_labels = re.findall(date_label_pattern, article_page, re.S)

            date_pattern = r'<span class="c-bibliographic-information__value"><time datetime="(.*?)".*?</span>'
            dates = re.findall(date_pattern, article_page, re.S)

            article_data = dict(zip(date_labels, dates))
            articles_data.append(article_data)

            count += 1
            print(f"Fetching article {count}/{num_articles}...")

            # Save results to a CSV file
            clean_title = re.sub(r'[<>:"/\\|?*]', '', journal_name)
            file_path = f'./Journal_Acceptance_Statistics/{clean_title}_latest_{num_articles}_articles.csv'
            fieldnames = ['Received', 'Revised', 'Accepted', 'Published', 'Issue Date']

            with open(file_path, 'w', encoding='utf-8', newline='') as file:
                writer = csv.DictWriter(file, fieldnames=fieldnames)
                writer.writeheader()
                writer.writerows(articles_data)

            # Stop fetching if the desired number of articles is reached
            if count >= num_articles:
                print('Query completed!')
                return

            time.sleep(2)


# Main function to keep the program running
while True:
    articles_data = []
    journal_issue_links = []

    print('Input rules: Words are case-insensitive, replace "&" with a space, and ensure proper spacing for "-" or "&".')
    journal_name = input('Enter the journal name (Enter "q" or "Q" to quit): ')

    if journal_name.lower() == 'q':
        break

    # Replace spaces in the journal name
    journal_name_query = replace_space(journal_name)

    # Construct the Springer search URL
    search_url = f'https://link.springer.com/search?facet-content-type=Journal&query={journal_name_query}'
    search_page = requests.get(url=search_url, headers=headers).text
    search_tree = etree.HTML(search_page)

    # Extract the journal ID from the search results
    href = search_tree.xpath('//a[@class="app-card-open__link"]/@href')
    if not href:
        print("No results found for the given journal name.")
        continue

    journal_id = href[0].split('/')[-1]

    # Construct the journal issues URL
    journal_url = f'https://link.springer.com/journal/{journal_id}/volumes-and-issues'
    journal_page = requests.get(url=journal_url, headers=headers).text
    journal_tree = etree.HTML(journal_page)

    # Extract issue links and names
    issue_links = journal_tree.xpath('//li[@class="c-list-group__item"]/a[@class="c-list-group__link c-list-group__link--bold"]/@href')
    issue_names = journal_tree.xpath('//li[@class="c-list-group__item"]/a[@class="c-list-group__link c-list-group__link--bold"]/text()')

    # Construct full URLs for the issues
    for link in issue_links:
        full_link = f'https://link.springer.com{link}'
        journal_issue_links.append(full_link)

    # Display available issues
    issue_data = dict(zip(issue_links[::-1], issue_names[::-1]))
    for issue, name in issue_data.items():
        print(f"Issue: {issue}, Name: {name}")

    # Choose mode
    mode = input('Enter 0 to query recent articles, 1 to query a specific volume-issue, or q to quit: ')
    if mode == '0':
        query_recent_articles()
    elif mode == '1':
        query_volume_issue()
    elif mode.lower() == 'q':
        break
    else:
        print("Invalid input. Please try again.")
# Out:
# Input rules: Words are case-insensitive, replace "&" with a space, and ensure proper spacing for "-" or "&".
# Issue: /journal/11134/volumes-and-issues/1-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/1-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/1-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/1-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/2-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/2-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/2-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/2-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/3-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/3-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/3-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/3-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/4-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/4-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/4-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/4-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/5-1, Name: Issue 1-3
# Issue: /journal/11134/volumes-and-issues/5-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/6-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/7-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/7-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/7-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/8-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/9-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/9-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/9-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/10-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/10-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/10-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/11-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/11-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/11-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/12-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/12-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/13-1, Name: Issue 1-3
# Issue: /journal/11134/volumes-and-issues/13-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/14-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/14-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/15-1, Name: Issue 1-4
# Issue: /journal/11134/volumes-and-issues/16-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/16-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/17-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/17-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/18-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/18-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/19-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/19-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/19-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/20-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/20-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/21-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/21-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/22-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/22-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/23-1, Name: Issue 1-4
# Issue: /journal/11134/volumes-and-issues/24-1, Name: Issue 1-4
# Issue: /journal/11134/volumes-and-issues/25-1, Name: Issue 1-4
# Issue: /journal/11134/volumes-and-issues/26-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/26-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/27-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/27-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/28-1, Name: Issue 1-3
# Issue: /journal/11134/volumes-and-issues/28-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/29-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/29-2, Name: Issue 2-4
# Issue: /journal/11134/volumes-and-issues/30-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/30-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/31-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/31-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/32-1, Name: Issue 1-3
# Issue: /journal/11134/volumes-and-issues/32-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/33-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/33-1, Name: Issue 1-3
# Issue: /journal/11134/volumes-and-issues/34-1, Name: Issue 1-4
# Issue: /journal/11134/volumes-and-issues/35-1, Name: Issue 1-4
# Issue: /journal/11134/volumes-and-issues/36-1, Name: Issue 1-3
# Issue: /journal/11134/volumes-and-issues/36-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/37-1, Name: Issue 1-3
# Issue: /journal/11134/volumes-and-issues/37-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/38-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/38-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/38-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/38-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/39-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/39-2, Name: Issue 2-3
# Issue: /journal/11134/volumes-and-issues/39-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/40-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/40-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/40-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/40-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/41-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/41-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/41-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/42-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/42-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/42-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/42-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/43-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/43-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/43-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/44-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/44-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/44-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/44-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/45-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/45-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/45-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/45-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/46-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/46-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/47-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/47-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/47-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/48-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/48-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/49-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/49-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/49-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/50-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/50-2, Name: Issue 2-3
# Issue: /journal/11134/volumes-and-issues/50-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/51-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/51-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/52-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/52-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/52-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/52-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/53-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/53-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/53-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/54-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/54-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/54-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/54-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/55-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/55-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/55-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/55-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/56-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/56-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/56-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/57-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/57-2, Name: Issue 2-3
# Issue: /journal/11134/volumes-and-issues/57-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/58-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/58-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/58-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/58-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/59-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/59-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/59-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/60-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/60-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/61-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/61-2, Name: Issue 2-3
# Issue: /journal/11134/volumes-and-issues/61-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/62-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/62-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/62-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/63-1, Name: Issue 1-4
# Issue: /journal/11134/volumes-and-issues/64-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/64-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/64-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/64-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/65-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/65-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/65-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/65-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/66-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/66-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/66-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/66-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/67-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/67-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/67-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/67-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/68-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/68-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/68-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/69-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/69-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/69-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/70-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/70-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/70-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/70-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/71-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/71-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/71-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/72-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/72-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/73-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/73-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/73-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/73-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/74-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/74-2, Name: Issue 2-3
# Issue: /journal/11134/volumes-and-issues/74-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/75-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/75-2, Name: Issue 2-4
# Issue: /journal/11134/volumes-and-issues/76-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/76-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/76-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/76-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/77-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/77-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/77-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/77-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/78-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/78-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/78-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/78-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/79-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/79-2, Name: Issue 2
# Issue: /journal/11134/volumes-and-issues/79-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/80-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/80-3, Name: Issue 3
# Issue: /journal/11134/volumes-and-issues/80-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/81-1, Name: Issue 1
# Issue: /journal/11134/volumes-and-issues/81-2, Name: Issue 2-3
# Issue: /journal/11134/volumes-and-issues/81-4, Name: Issue 4
# Issue: /journal/11134/volumes-and-issues/82-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/82-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/83-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/83-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/84-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/84-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/85-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/85-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/86-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/86-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/87-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/87-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/88-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/88-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/89-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/89-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/90-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/90-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/91-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/91-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/92-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/92-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/93-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/93-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/94-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/94-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/95-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/95-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/96-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/96-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/97-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/97-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/98-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/98-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/99-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/99-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/100-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/100-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/101-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/101-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/102-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/102-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/103-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/103-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/104-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/104-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/105-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/105-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/106-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/106-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/107-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/107-3, Name: Issue 3-4
# Issue: /journal/11134/volumes-and-issues/108-1, Name: Issue 1-2
# Issue: /journal/11134/volumes-and-issues/108-3, Name: Issue 3-4
# Processing URL: https://link.springer.com/journal/11134/volumes-and-issues/108-3
# Fetching articles for Volume 108, Issue 3...
# Fetching article 1/50...
# Fetching article 2/50...
# Fetching article 3/50...
# Fetching article 4/50...
# Fetching article 5/50...
# Fetching article 6/50...
# Fetching article 7/50...
# Fetching article 8/50...
# Fetching article 9/50...
# Processing URL: https://link.springer.com/journal/11134/volumes-and-issues/108-1
# Fetching articles for Volume 108, Issue 1...
# Fetching article 10/50...
# Fetching article 11/50...
# Fetching article 12/50...
# Fetching article 13/50...
# Fetching article 14/50...
# Processing URL: https://link.springer.com/journal/11134/volumes-and-issues/107-3
# Fetching articles for Volume 107, Issue 3...
# Fetching article 15/50...
# Fetching article 16/50...
# Fetching article 17/50...
# Fetching article 18/50...
# Processing URL: https://link.springer.com/journal/11134/volumes-and-issues/107-1
# Fetching articles for Volume 107, Issue 1...
# Fetching article 19/50...
# Fetching article 20/50...
# Fetching article 21/50...
# Fetching article 22/50...
# Fetching article 23/50...
# Processing URL: https://link.springer.com/journal/11134/volumes-and-issues/106-3
# Fetching articles for Volume 106, Issue 3...
# Fetching article 24/50...
# Fetching article 25/50...
# Fetching article 26/50...
# Fetching article 27/50...
# Fetching article 28/50...
# Processing URL: https://link.springer.com/journal/11134/volumes-and-issues/106-1
# Fetching articles for Volume 106, Issue 1...
# Fetching article 29/50...
# Fetching article 30/50...
# Fetching article 31/50...
# Fetching article 32/50...
# Processing URL: https://link.springer.com/journal/11134/volumes-and-issues/105-3
# Fetching articles for Volume 105, Issue 3...
# Fetching article 33/50...
# Fetching article 34/50...
# Fetching article 35/50...
# Fetching article 36/50...
# Fetching article 37/50...
# Fetching article 38/50...
# Processing URL: https://link.springer.com/journal/11134/volumes-and-issues/105-1
# Fetching articles for Volume 105, Issue 1...
# Fetching article 39/50...
# Fetching article 40/50...
# Fetching article 41/50...
# Fetching article 42/50...
# Fetching article 43/50...
# Fetching article 44/50...
# Fetching article 45/50...
# Processing URL: https://link.springer.com/journal/11134/volumes-and-issues/104-3
# Fetching articles for Volume 104, Issue 3...
# Fetching article 46/50...
# Fetching article 47/50...
# Fetching article 48/50...
# Fetching article 49/50...
# Fetching article 50/50...
# Query completed!
# Input rules: Words are case-insensitive, replace "&" with a space, and ensure proper spacing for "-" or "&".
